# %%
#Import Statements
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "sans-serif"
import seaborn as sns

sns.set() # Setting seaborn as default style
sns.set_theme()

# %%
# Columns below this comment are as follows:
# 1. Time results were received.
# 2. MD5 hash of participant's IP address.
# 3. Controller name.
# 4. Item number.
# 5. Element number.
# 6. Type.
# 7. Group.
# 8. Field name.
# 9. Field value.
df = pd.read_csv('../data/results_vp_hours.txt',
                 sep = ',',
                 comment='#', 
                 header=None,
                 names = ['time','hash','controller','item','element', 'type', 'group','field_name', 'value'],
                engine = 'python')

# %%
names = df.iloc[::3, :]['value']
emails = df.iloc[1::3, :]['value']
names = names.reset_index(drop=True)
emails = emails.reset_index(drop=True)
vp = pd.DataFrame({'name': names,'email':emails,})
vp.to_csv('vp_hour_list.csv', index = False, encoding='utf-8')
vp
# Out:
#                        name                           email
# 0                 Test Name                    test@name.de
# 1             Petau%2C Aron                  aron@petau.net
# 2             Petau%2C Aron                  aron@petau.net
# 3              Pries%2C Tom                   tpries@uos.de
# 4         Bödiker%2C Jasmin     Jboediker@uni-osnabrueck.de
# 5           Klehr%2C Marcel                   mklehr@uos.de
# 6        Anna Luise Backsen       abacksen@uni-osnabrück.de
# 7         Richert%2C Hannah      hrichert@uni-osnabrueck.de
# 8          Bracht%2C Rahel                   rbracht@uos.de
# 9            Timm%2C Franka                    ftimm@uos.de
# 10            Starke%2C Per              per@starke-team.de
# 11          Litsch%2C Jakob                  jlitsch@uos.de
# 12           Otten%2C Jonas                  jootten@uos.de
# 13        Jan-Luca Schröder             janlschroede@uos.de
# 14         Fiedler%2C Clara                clfiedler@uos.de
# 15          Giebken%2C Lara      lgiebken@uni-osnabrueck.de
# 16         Webers%2C Hannah            hannah.webers@gmx.de
# 17         Ashitey%2C Sarah            sarah.ashitey@gmx.de
# 18          Jensen%2C Alina        alina.jensen97@gmail.com
# 19           Jänsch%2C Paul     pajaensch@uni-osnabrueck.de
# 20        Willkomm%2C Hanna     hwillkomm@uni-osnabrueck.de
# 21         Tiemann%2C Laura    lautiemann@uni-osnabrueck.de
# 22         Simon%2C Jessica       jesimon@uni-osnabrueck.de
# 23           Kohne%2C Rahel                   rkohne@gmx.de
# 24   Schmidt%2C Hendrik Jon   hendschmidt@uni-osnabrueck.de
# 25           Ewert%2C Milan        mewert@uni-osnabrueck.de
# 26         Nickel%2C Frauke            frauke.nickel@gmx.de
# 27        Karas%2C Valeria              valeriakaras@web.de
# 28     Claassen%2C Johannes     jclaassen@uni-osnabrueck.de
# 29            Louisa Peters             peterslouisa@web.de
# 30            Lülf%2C Sönke                   sluelf@uos.de
# 31         Stölting%2C Lara  llastoelting@uni-osnabrueck.de
# 32       Ullrich%2C Yannik       yullrich@uni-osnabrueck.de
# 33  von Butler%2C Eva-Marie    evonbutler@uni-osnabrueck.de
# 34       Henrik Himmelreich             hhimmelreich@uos.de
# 35         Weimer%2C Olesja       oweimer@uni-osnabrueck.de
